# %%
# !pip install -e .. --user
# Out:
# Obtaining file:///C:/Users/gabeh/Code/super_resolution
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: super-resolution
#     Found existing installation: super-resolution 0.2.4
#     Uninstalling super-resolution-0.2.4:
#       Successfully uninstalled super-resolution-0.2.4
#   Running setup.py develop for super-resolution
# ...

# %%
import requests
import io
import numpy as np
from PIL import Image

from super_resolution import cartoon_upsampling_8x, cartoon_upsampling_4x
# Out:
# WARNING:tensorflow:From C:\Users\gabeh\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
img_url = 'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fstatic.tvtropes.org%2Fpmwiki%2Fpub%2Fimages%2F12oz-Mouse-Fitz.png&f=1&nofb=1'
res = requests.get(img_url, stream = True)

img = np.array(Image.open(io.BytesIO(res.content)))

pil_image = Image.fromarray(img)
display(pil_image)
# Out:
# <PIL.Image.Image image mode=RGB size=364x300>

# %%
upscaled = cartoon_upsampling_8x(img)
upscaled_pil = Image.fromarray(upscaled)
display(upscaled_pil)
# Out:
# WARNING:tensorflow:From C:\Users\gabeh\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\init_ops.py:93: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\gabeh\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\init_ops.py:93: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
upscaled = cartoon_upsampling_4x(img)
upscaled_pil = Image.fromarray(upscaled)
display(upscaled_pil)
# Out:
# downloading model file C:\Users\gabeh\.deepoffice\super_resolution\model\super_resolution_4x\js.json from https://github.com/fengwang/super_resolution/releases/download/0.3/js.json
# downloaded model file C:\Users\gabeh\.deepoffice\super_resolution\model\super_resolution_4x\js.json from https://github.com/fengwang/super_resolution/releases/download/0.3/js.json
# downloading model file C:\Users\gabeh\.deepoffice\super_resolution\model\super_resolution_4x\weights.h5 from https://github.com/fengwang/super_resolution/releases/download/0.3/weights.h5
# downloaded model file C:\Users\gabeh\.deepoffice\super_resolution\model\super_resolution_4x\weights.h5 from https://github.com/fengwang/super_resolution/releases/download/0.3/weights.h5
# <PIL.Image.Image image mode=RGB size=1456x1200>
